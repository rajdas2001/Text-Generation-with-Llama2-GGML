# %% [markdown]
# <a href="https://colab.research.google.com/github/rajdas2001/Text-Generation-with-Llama2-GGML/blob/main/Text_Generation_with_with_Llama2_GGML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q ctransformers langchain
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 31.7 MB/s eta 0:00:00

# %%
from langchain.llms import CTransformers
from langchain import PromptTemplate, LLMChain
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
llm = CTransformers(model="TheBloke/Llama-2-7B-Chat-GGML", model_file = 'llama-2-7b-chat.ggmlv3.q2_K.bin', callbacks=[StreamingStdOutCallbackHandler()])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# llama-2-7b-chat.ggmlv3.q2_K.bin:   0%|          | 0.00/2.87G [00:00<?, ?B/s]

# %%
template = """
[INST] <<SYS>>
You are a helpful, respectful and honest assistant. Your answers are always brief.
<</SYS>>
{text}[/INST]
"""

prompt = PromptTemplate(template=template, input_variables=["text"])

# %%
llm_chain = LLMChain(prompt=prompt, llm=llm)

# %%
user_question = input("Enter your question here: ")
# Out:
# Enter your question here: How to make a sandwich?

# %%
response = llm_chain.run(user_question)
print(response)
# Out:
# To make a sandwich, you will need:
#
# * Bread (preferably your favorite type)
# * Protein of your choice (e.g. turkey, ham, chicken, tuna, etc.)
# * Vegetables (lettuce, tomato, cucumber, etc.)
# * Cheese (optional)
# * Condiments (mayonnaise, mustard, ketchup, etc.)
#
# Here's a basic template for making a sandwich:
#
# 1. Lay out the bread slices on a plate or cutting board.
# 2. Add protein of your choice to the top or bottom of the bread.
# 3. Add vegetables and/or cheese on top of the protein.
# 4. Apply condiments as desired.
# 5. Assemble the sandwich by placing the top slice of bread on top of the other slices.
# 6. Cut the sandwich into individual pieces, if desired.
# 7. Serve and enjoy!
#
# Note: You can also get creative with different types of bread, meats, cheeses, and condiments to create unique and delicious sandwich combinations.To make a sandwich, you will need:
#
# * Bread (preferably your favorite type)
# ...
